# %% [markdown]
# ### Analisis de los CSV

# %% [markdown]
# Importamos modulos y librerias

# %%
import pandas as pd

# %%
csv_2015 = '../data/2015.csv'
csv_2016 = '../data/2016.csv'
csv_2017 = '../data/2017.csv'
csv_2018 = '../data/2018.csv'
csv_2019 = '../data/2019.csv'

# %% [markdown]
# Leemos los csv como un dataframe, cada uno con su respectivo año

# %%
df_2015 = pd.read_csv(csv_2015, sep=',', encoding='latin-1')
df_2016 = pd.read_csv(csv_2016, sep=',', encoding='latin-1')
df_2017 = pd.read_csv(csv_2017, sep=',', encoding='latin-1')
df_2018 = pd.read_csv(csv_2018, sep=',', encoding='latin-1')
df_2019 = pd.read_csv(csv_2019, sep=',', encoding='latin-1')

# %% [markdown]
# ### CSV 2015
#
# Conocemos sobre como se encuentran los datos del csv_2015

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %% [markdown]
# Una vista previa en como se ven los datos del df_2015

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# Contamos con estas columnas

# %%
df_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df_2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %% [markdown]
# ### CSV 2016
#
# Observamos el tipo de dato que se encuentra en el df_2016

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
#  12  Dystopia Residual              157 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 16.1+ KB

# %% [markdown]
# Una vista previa en como se ven los datos

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %% [markdown]
# Estas son las columnas que contiene el df

# %%
df_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df_2016.describe()
# Out:
#        Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# count      157.000000       157.000000              157.000000
# mean        78.980892         5.382185                0.953880
# std         45.466030         1.141674                0.412595
# min          1.000000         2.905000                0.000000
# 25%         40.000000         4.404000                0.670240
# 50%         79.000000         5.314000                1.027800
# 75%        118.000000         6.269000                1.279640
# max        157.000000         7.526000                1.824270
#
#        Social_Support  Health_Life_Expectancy     Freedom  Corruption  \
# count      157.000000              157.000000  157.000000  157.000000
# mean         0.793621                0.557619    0.370994    0.137624
# std          0.266706                0.229349    0.145507    0.111038
# min          0.000000                0.000000    0.000000    0.000000
# 25%          0.641840                0.382910    0.257480    0.061260
# 50%          0.841420                0.596590    0.397470    0.105470
# 75%          1.021520                0.729930    0.484530    0.175540
# max          1.183260                0.952770    0.608480    0.505210
#
#        Generosity    Year
# count  157.000000   157.0
# mean     0.242635  2016.0
# std      0.133756     0.0
# min      0.000000  2016.0
# 25%      0.154570  2016.0
# 50%      0.222450  2016.0
# 75%      0.311850  2016.0
# max      0.819710  2016.0

# %% [markdown]
# ### CSV 2017

# %%
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 14.7+ KB

# %%
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df_2017.describe()
# Out:
#        Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# count      155.000000       155.000000              155.000000
# mean        78.000000         5.354019                0.984718
# std         44.888751         1.131230                0.420793
# min          1.000000         2.693000                0.000000
# 25%         39.500000         4.505500                0.663371
# 50%         78.000000         5.279000                1.064578
# 75%        116.500000         6.101500                1.318027
# max        155.000000         7.537000                1.870766
#
#        Social_Support  Health_Life_Expectancy     Freedom  Generosity  \
# count      155.000000              155.000000  155.000000  155.000000
# mean         1.188898                0.551341    0.408786    0.246883
# std          0.287263                0.237073    0.149997    0.134780
# min          0.000000                0.000000    0.000000    0.000000
# 25%          1.042635                0.369866    0.303677    0.154106
# 50%          1.253918                0.606042    0.437454    0.231538
# 75%          1.414316                0.723008    0.516561    0.323762
# max          1.610574                0.949492    0.658249    0.838075
#
#        Corruption    Year
# count  155.000000   155.0
# mean     0.123120  2017.0
# std      0.101661     0.0
# min      0.000000  2017.0
# 25%      0.057271  2017.0
# 50%      0.089848  2017.0
# 75%      0.153296  2017.0
# max      0.464308  2017.0

# %% [markdown]
# ### CSV 2018

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# Eliminamos el valor nulo que se encuentra en el df

# %%
df_2018 = df_2018.dropna()

# %%
df_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
df_2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df_2018.describe()
# Out:
#        Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# count      155.000000       155.000000              155.000000
# mean        78.877419         5.366897                0.883677
# std         45.076463         1.117433                0.380942
# min          1.000000         2.905000                0.000000
# 25%         40.500000         4.451500                0.612500
# 50%         79.000000         5.358000                0.940000
# 75%        117.500000         6.154000                1.192500
# max        156.000000         7.632000                1.649000
#
#        Social_Support  Health_Life_Expectancy     Freedom  Generosity  \
# count      155.000000              155.000000  155.000000  155.000000
# mean         1.216058                0.596877    0.455606    0.180974
# std          0.301286                0.248312    0.162367    0.098789
# min          0.000000                0.000000    0.000000    0.000000
# 25%          1.075500                0.420500    0.357500    0.109000
# 50%          1.258000                0.643000    0.493000    0.173000
# 75%          1.464000                0.778500    0.579000    0.240000
# max          1.644000                1.030000    0.724000    0.598000
#
#        Corruption    Year
# count  155.000000   155.0
# mean     0.112000  2018.0
# std      0.096492     0.0
# min      0.000000  2018.0
# 25%      0.051000  2018.0
# 50%      0.082000  2018.0
# 75%      0.137000  2018.0
# max      0.457000  2018.0

# %% [markdown]
# ### CSV 2019

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
df_2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df_2019.describe()
# Out:
#        Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# count      156.000000       156.000000              156.000000
# mean        78.500000         5.407096                0.905147
# std         45.177428         1.113120                0.398389
# min          1.000000         2.853000                0.000000
# 25%         39.750000         4.544500                0.602750
# 50%         78.500000         5.379500                0.960000
# 75%        117.250000         6.184500                1.232500
# max        156.000000         7.769000                1.684000
#
#        Social_Support  Health_Life_Expectancy     Freedom  Generosity  \
# count      156.000000              156.000000  156.000000  156.000000
# mean         1.208814                0.725244    0.392571    0.184846
# std          0.299191                0.242124    0.143289    0.095254
# min          0.000000                0.000000    0.000000    0.000000
# 25%          1.055750                0.547750    0.308000    0.108750
# 50%          1.271500                0.789000    0.417000    0.177500
# 75%          1.452500                0.881750    0.507250    0.248250
# max          1.624000                1.141000    0.631000    0.566000
#
#        Corruption    Year
# count  156.000000   156.0
# mean     0.110603  2019.0
# std      0.094538     0.0
# min      0.000000  2019.0
# 25%      0.047000  2019.0
# 50%      0.085500  2019.0
# 75%      0.141250  2019.0
# max      0.453000  2019.0

# %% [markdown]
# ### Valores nulos de los df

# %% [markdown]
# Podemos verirficar que no contamos con valores nulos en los dataframe, esto es muy importante al momento de realizar el entrenamiento del modelo

# %%
dataframes = [df_2015, df_2016, df_2017, df_2018, df_2019]

# Función para calcular el total de valores nulos en cada DataFrame
def total_nulos(dataframes):
    total = []
    for df in dataframes:
        total_nulos_df = df.isnull().sum().sum()
        total.append(total_nulos_df)
    return total

# Calcular el total de valores nulos en cada DataFrame
total_nulos_por_df = total_nulos(dataframes)

# Imprimir los resultados
for i, total in enumerate(total_nulos_por_df, start=2015):
    print(f"Total de valores nulos en df_{i}: {total}")
# Out:
# Total de valores nulos en df_2015: 0
# Total de valores nulos en df_2016: 0
# Total de valores nulos en df_2017: 0
# Total de valores nulos en df_2018: 0
# Total de valores nulos en df_2019: 0

# %% [markdown]
# Podemos observar como hay mas informacion de otros campos en los dataset

# %%
def num_columnas(dataframes):
    num_columnas_lista = []
    for df in dataframes:
        num_columnas_df = df.shape[1]  # El número de columnas es el segundo elemento de la tupla shape
        num_columnas_lista.append(num_columnas_df)
    return num_columnas_lista

# Calcular el número de columnas en cada DataFrame
num_columnas_por_df = num_columnas(dataframes)

# Imprimir los resultados
for i, num_columnas in enumerate(num_columnas_por_df, start=2015):
    print(f"Número de columnas en df_{i}: {num_columnas}")
# Out:
# Número de columnas en df_2015: 12
# Número de columnas en df_2016: 13
# Número de columnas en df_2017: 12
# Número de columnas en df_2018: 9
# Número de columnas en df_2019: 9

# %% [markdown]
# ### Estandarizar Nombre de las columnas

# %% [markdown]
# Para poder realizar un buen merge de los 5 csv debemos estandarizar sus columnas por lo cual lo realizamos por partes. EN esta funcion vamos a estandarizar los de 2015 y 2016 ya que cuentan con una misma estructura en el nombre de las columnas

# %%
def standardize_column_names(df):
    # Map old column names to new names
    new_column_names = {
        'Country': 'Country',
        'Region': 'Region',
        'Happiness Rank': 'Happiness_Rank',
        'Happiness Score': 'Happiness_Score',
        'Standard Error': 'Standard_Error',
        'Economy (GDP per Capita)': 'Economy_GDP_per_Capita',
        'Family': 'Social_Support',
        'Health (Life Expectancy)': 'Health_Life_Expectancy',
        'Freedom': 'Freedom',
        'Trust (Government Corruption)': 'Corruption',
        'Generosity': 'Generosity',
        'Dystopia Residual': 'Dystopia_Residual'
    }

    # Rename columns using the mapping dictionary
    df.rename(columns=new_column_names, inplace=True)

# %%
standardize_column_names(df_2015)
standardize_column_names(df_2016)

# %%
df_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness_Rank', 'Happiness_Score',
#        'Standard_Error', 'Economy_GDP_per_Capita', 'Social_Support',
#        'Health_Life_Expectancy', 'Freedom', 'Corruption', 'Generosity',
#        'Dystopia_Residual'],
#       dtype='object')

# %%
df_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness_Rank', 'Happiness_Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy_GDP_per_Capita', 'Social_Support', 'Health_Life_Expectancy',
#        'Freedom', 'Corruption', 'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %% [markdown]
# En esta segunda parte realizamos una funcion para 2017 que cuenta con . en los espacios de las palabras

# %%
def standardize_column(df):
    # Map old column names to new names
    new_column_names = {
        'Country': 'Country',
        'Happiness.Rank': 'Happiness_Rank',
        'Happiness.Score': 'Happiness_Score',
        'Whisker.high': 'Whisker_High',
        'Whisker.low': 'Whisker_Low',
        'Economy..GDP.per.Capita.': 'Economy_GDP_per_Capita',
        'Family': 'Social_Support',
        'Health..Life.Expectancy.': 'Health_Life_Expectancy',
        'Freedom': 'Freedom',
        'Generosity': 'Generosity',
        'Trust..Government.Corruption.': 'Corruption',
        'Dystopia.Residual': 'Dystopia_Residual'
    }

    # Rename columns using the mapping dictionary
    df.rename(columns=new_column_names, inplace=True)

# %%
standardize_column(df_2017)

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness_Rank', 'Happiness_Score', 'Whisker_High',
#        'Whisker_Low', 'Economy_GDP_per_Capita', 'Social_Support',
#        'Health_Life_Expectancy', 'Freedom', 'Generosity', 'Corruption',
#        'Dystopia_Residual'],
#       dtype='object')

# %% [markdown]
# En esta parte se tuvo en cuenta que Happiness score no se encuentra como en las otros df pero es porque lo toman solo coo score al igual que Happiness rank esta como overral rank.

# %%
def standardize(df):
    # Map old column names to new names
    new_column_names = {
        'Overall rank': 'Happiness_Rank',
        'Country or region': 'Country',
        'Score': 'Happiness_Score',
        'GDP per capita': 'Economy_GDP_per_Capita',
        'Social support': 'Social_Support',
        'Healthy life expectancy': 'Health_Life_Expectancy',
        'Freedom to make life choices': 'Freedom',
        'Generosity': 'Generosity',
        'Perceptions of corruption': 'Corruption'
    }

    # Rename columns using the mapping dictionary
    df.rename(columns=new_column_names, inplace=True)

# %%
standardize(df_2018)
standardize(df_2019)

# %%
df_2018.columns
# Out:
# Index(['Happiness_Rank', 'Country', 'Happiness_Score',
#        'Economy_GDP_per_Capita', 'Social_Support', 'Health_Life_Expectancy',
#        'Freedom', 'Generosity', 'Corruption'],
#       dtype='object')

# %%
df_2019.columns
# Out:
# Index(['Happiness_Rank', 'Country', 'Happiness_Score',
#        'Economy_GDP_per_Capita', 'Social_Support', 'Health_Life_Expectancy',
#        'Freedom', 'Generosity', 'Corruption'],
#       dtype='object')

# %% [markdown]
# ### Columnas a eliminar
# df_ 2015 = Standard_Error
#
# df_2016 = Lower Confidence Interval', 'Upper Confidence Interval'
#
# df_2017 = 'Whisker_High', 'Whisker_Low'

# %% [markdown]
# Se tuvo encuenta eliminar estas columnas en los df ya que es informacion que solo se encuentra en estos df y no se comparten con los demas, lo que hara si se dejan es producir valores nulos en el merge final que no es conveniente para realizar el modelo.

# %%
df_2015 = df_2015.drop(['Region', 'Standard_Error', 'Dystopia_Residual'], axis=1)

df_2016 = df_2016.drop(['Region', 'Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia_Residual'], axis=1)

df_2017 = df_2017.drop(['Whisker_High', 'Whisker_Low', 'Dystopia_Residual'], axis=1)

# %% [markdown]
# Añadimos una columna en cada df del año correspondiente de la informacion

# %%
df_2015['Year'] = 2015
df_2016['Year'] = 2016
df_2017['Year'] = 2017
df_2018['Year'] = 2018
df_2019['Year'] = 2019

# %% [markdown]
# Podemos observar que todos los df cuentan con el mismo numero de columnas

# %%
from tabulate import tabulate

def num_columnas(dataframes):
    num_columnas_lista = []
    for df in dataframes:
        num_columnas_df = df.shape[1]  # Obtener el número de columnas
        num_columnas_lista.append(num_columnas_df)
    return num_columnas_lista

# Calcular el número de columnas en cada DataFrame
num_columnas_por_df = num_columnas([df_2015, df_2016, df_2017, df_2018, df_2019])

# Crear una lista de listas para la tabla
tabla_datos = []
for i, num_columnas in enumerate(num_columnas_por_df, start=2015):
    tabla_datos.append([f"df_{i}", num_columnas])

# Imprimir la tabla
print(tabulate(tabla_datos, headers=["DataFrame", "Número de Columnas"], tablefmt="grid"))
# Out:
# +-------------+----------------------+
# | DataFrame   |   Número de Columnas |
# +=============+======================+
# | df_2015     |                   10 |
# +-------------+----------------------+
# | df_2016     |                   10 |
# +-------------+----------------------+
# | df_2017     |                   10 |
# +-------------+----------------------+
# | df_2018     |                   10 |
# +-------------+----------------------+
# | df_2019     |                   10 |
# +-------------+----------------------+

# %% [markdown]
# ### Union de  los dataframe

# %% [markdown]
# Realizamos una concatenacion de los cinco df

# %%
df = pd.concat([df_2015, df_2016, df_2017, df_2018, df_2019], ignore_index=True)

# %% [markdown]
# Observamos una vista previa del df final

# %%
df.head()
# Out:
#        Country  Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# 0  Switzerland               1            7.587                 1.39651
# 1      Iceland               2            7.561                 1.30232
# 2      Denmark               3            7.527                 1.32548
# 3       Norway               4            7.522                 1.45900
# 4       Canada               5            7.427                 1.32629
#
#    Social_Support  Health_Life_Expectancy  Freedom  Corruption  Generosity  \
# 0         1.34951                 0.94143  0.66557     0.41978     0.29678
# 1         1.40223                 0.94784  0.62877     0.14145     0.43630
# 2         1.36058                 0.87464  0.64938     0.48357     0.34139
# 3         1.33095                 0.88521  0.66973     0.36503     0.34699
# 4         1.32261                 0.90563  0.63297     0.32957     0.45811
#
#    Year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %% [markdown]
# El df final cuenta con 781 registros y 10 columnas

# %%
df.shape
# Out:
# (781, 10)

# %% [markdown]
# Observamos que no se encuentran ningun valor nulo en el df final

# %%
df.isnull().sum()
# Out:
# Country                   0
# Happiness_Rank            0
# Happiness_Score           0
# Economy_GDP_per_Capita    0
# Social_Support            0
# Health_Life_Expectancy    0
# Freedom                   0
# Corruption                0
# Generosity                0
# Year                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 781 entries, 0 to 780
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Happiness_Rank          781 non-null    int64
#  1   Happiness_Score         781 non-null    float64
#  2   Economy_GDP_per_Capita  781 non-null    float64
#  3   Social_Support          781 non-null    float64
#  4   Health_Life_Expectancy  781 non-null    float64
#  5   Freedom                 781 non-null    float64
#  6   Corruption              781 non-null    float64
#  7   Generosity              781 non-null    float64
#  8   Year                    781 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 55.0 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation_matrix = df.corr()

# Configurar el tamaño del gráfico
plt.figure(figsize=(10, 8))

# Generar mapa de calor con Seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)

# Añadir título
plt.title('Matriz de Correlación de los Datos Fusionados')

# Mostrar el gráfico
plt.show()

# %%
# Histogramas para cada variable
df.hist(figsize=(10, 8))
plt.show()

# %%
from sklearn.feature_selection import SelectKBest, f_regression

# Selección de características utilizando prueba F
X = df.drop(columns=['Happiness_Score', 'Happiness_Rank'])
y = df['Happiness_Score']
selector = SelectKBest(score_func=f_regression, k=5)
X_new = selector.fit_transform(X, y)
selected_features = X.columns[selector.get_support()]
print("Características seleccionadas:", selected_features)
# Out:
# Características seleccionadas: Index(['Economy_GDP_per_Capita', 'Social_Support', 'Health_Life_Expectancy',
#        'Freedom', 'Corruption'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Happiness_Score'], kde=True)
plt.title('Distribución del Happiness_Score')
plt.xlabel('Happiness_Score')
plt.ylabel('Frecuencia')
plt.show()

# %%
correlation_with_happiness = df.corr()['Happiness_Score'].sort_values(ascending=False)
print(correlation_with_happiness)
# Out:
# Happiness_Score           1.000000
# Economy_GDP_per_Capita    0.789719
# Health_Life_Expectancy    0.742843
# Social_Support            0.651246
# Freedom                   0.553365
# Corruption                0.398418
# Generosity                0.138142
# Year                      0.005946
# Happiness_Rank           -0.992053
# Name: Happiness_Score, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Supongamos que 'df' es el DataFrame fusionado que contiene todas las columnas mencionadas
# Asegúrate de que 'Happiness_Score' está correctamente nombrada en tu DataFrame

# Calcular la matriz de correlación
correlation_matrix = df.corr()

# Seleccionar las cinco variables más correlacionadas con 'Happiness_Score'
top_5_variables = correlation_matrix['Happiness_Score'].abs().sort_values(ascending=False).index[1:6]

# Crear gráficos de dispersión para las cinco variables más correlacionadas
sns.set(color_codes=True)
for variable in top_5_variables:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=df[variable], y=df['Happiness_Score'], hue=df['Happiness_Score'], palette='coolwarm')
    plt.title(f'Scatter Plot: {variable} vs Happiness Score')
    plt.xlabel(variable)
    plt.ylabel('Happiness Score')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la correlación entre todas las variables y 'Happiness Score'
correlation_with_happiness = df.corr()['Happiness_Score'].sort_values(ascending=False)

# Seleccionar las cinco variables más correlacionadas
top_5_variables = correlation_with_happiness.index[1:6]  # Excluye 'Happiness Score' que tiene correlación 1 consigo misma

# Crear gráficos de dispersión para las cinco variables más correlacionadas
sns.set(color_codes=True)
for variable in top_5_variables:
    sns.scatterplot(x=variable, y='Happiness_Score', hue='Happiness_Score', data=df)
    plt.title(f'Scatter Plot: {variable} vs Happiness Score')
    plt.show()

# %% [markdown]
# ### Modelo Regresion Lineal

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# Seleccionar las características y el target
X = df[['Economy_GDP_per_Capita', 'Social_Support', 'Health_Life_Expectancy', 'Freedom', 'Corruption', 'Generosity']]
y = df['Happiness_Score']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# Inicializar el modelo de regresión lineal
model = LinearRegression()

# Entrenar el modelo en el conjunto de entrenamiento
model.fit(X_train, y_train)

# Predecir en el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular el error cuadrático medio (MSE) en el conjunto de prueba
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
r2_score = model.score(X_test, y_test)
print("R² Score:", r2_score)
# Out:
# Mean Squared Error: 0.2707466313382097
# R² Score: 0.789470043609707

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# Seleccionar las características y el target
X = df[['Economy_GDP_per_Capita', 'Social_Support', 'Health_Life_Expectancy', 'Freedom', 'Corruption', 'Generosity','Year']]
y = df['Happiness_Score']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=59)

# Inicializar el modelo de regresión lineal
model = LinearRegression()

# Entrenar el modelo en el conjunto de entrenamiento
model.fit(X_train, y_train)

# Predecir en el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular el coeficiente de determinación (R²) en el conjunto de prueba
r2_score = r2_score(y_test, y_pred)
print("R² Score:", r2_score)
# Out:
# R² Score: 0.8255458687623125

# %%
df = df.drop('Country',axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Crear modelo de Random Forest
random_forest_model = RandomForestRegressor(n_estimators=100, random_state=1)

# Entrenar el modelo con los datos de entrenamiento
random_forest_model.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred_rf = random_forest_model.predict(X_test)

# Calcular métricas de evaluación
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

# Imprimir resultados
print("Random Forest Regression Model Results:")
print("Mean Squared Error (MSE):", mse_rf)
print("Coefficient of determination (R^2):", r2_rf)
# Out:
# Random Forest Regression Model Results:
# Mean Squared Error (MSE): 0.18741993042417307
# Coefficient of determination (R^2): 0.8653402375319119

# %%
import matplotlib.pyplot as plt

# Graficar valores predichos vs valores reales
plt.scatter(y_test, y_pred_rf, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linewidth=2)
plt.xlabel('Valores Reales')
plt.ylabel('Valores Predichos')
plt.title('Random Forest Regression: Valores Predichos vs Valores Reales')
plt.show()

# %%
# Obtener importancia de las características
importances = random_forest_model.feature_importances_

# Ordenar características por importancia
sorted_indices = importances.argsort()[::-1]
sorted_importances = importances[sorted_indices]
sorted_features = X_train.columns[sorted_indices]

# Graficar importancia de las características
plt.figure(figsize=(10, 6))
plt.bar(range(X_train.shape[1]), sorted_importances, tick_label=sorted_features)
plt.xticks(rotation=90)
plt.xlabel('Características')
plt.ylabel('Importancia')
plt.title('Importancia de las Características en Random Forest Regression')
plt.show()

# %%
residuos = y_test - y_pred_rf
plt.scatter(y_pred_rf, residuos)
plt.xlabel('Valores Predichos')
plt.ylabel('Residuos')
plt.title('Análisis de Residuos')
plt.axhline(y=0, color='r', linestyle='-')
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# Realizar validación cruzada
scores = cross_val_score(random_forest_model, X_train, y_train, cv=5, scoring='r2')
print("R^2 promedio durante validación cruzada:", scores.mean())
# Out:
# R^2 promedio durante validación cruzada: 0.7848536279947023

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# Inicializar modelos
linear_reg_model = LinearRegression()
ridge_model = Ridge(alpha=1.0)
lasso_model = Lasso(alpha=1.0)

# Entrenar modelos
linear_reg_model.fit(X_train, y_train)
ridge_model.fit(X_train, y_train)
lasso_model.fit(X_train, y_train)

# Evaluar modelos
r2_linear = linear_reg_model.score(X_test, y_test)
r2_ridge = ridge_model.score(X_test, y_test)
r2_lasso = lasso_model.score(X_test, y_test)

print("R^2 para Regresión Lineal:", r2_linear)
print("R^2 para Ridge Regression:", r2_ridge)
print("R^2 para Lasso Regression:", r2_lasso)
# Out:
# R^2 para Regresión Lineal: 0.8255458687623125
# R^2 para Ridge Regression: 0.8241128833727527
# R^2 para Lasso Regression: -0.011091835732024657

# %%
X_test.to_csv('../data/x_test_data.csv', index = False)
y_test.to_csv('../data/y_test_data.csv', index = False)

# %%
test_data_30_percent = pd.concat([X_test, y_test], axis=1)

# %%
test_data_20_percent = pd.concat([X_test, y_test], axis=1)

# %%
test_data_30_percent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 425 to 49
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Economy_GDP_per_Capita  157 non-null    float64
#  1   Social_Support          157 non-null    float64
#  2   Health_Life_Expectancy  157 non-null    float64
#  3   Freedom                 157 non-null    float64
#  4   Corruption              157 non-null    float64
#  5   Generosity              157 non-null    float64
#  6   Year                    157 non-null    int64
#  7   Happiness_Score         157 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 11.0 KB

# %%
test_data_20_percent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 425 to 49
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Economy_GDP_per_Capita  157 non-null    float64
#  1   Social_Support          157 non-null    float64
#  2   Health_Life_Expectancy  157 non-null    float64
#  3   Freedom                 157 non-null    float64
#  4   Corruption              157 non-null    float64
#  5   Generosity              157 non-null    float64
#  6   Year                    157 non-null    int64
#  7   Happiness_Score         157 non-null    float64
# dtypes: float64(7), int64(1)
# memory usage: 11.0 KB

# %%
y_test.head()
# Out:
# 425    4.574
# 487    6.886
# 152    3.575
# 15     6.983
# 5      7.406
# Name: Happiness_Score, dtype: float64

# %% [markdown]
# ### Exportar modelo

# %%
import joblib

joblib.dump(random_forest_model, 'random_forest_model.pkl')

loaded_model = joblib.load('random_forest_model.pkl')
